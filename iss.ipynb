# %% [markdown]
# Module 5 Assignment: Tracking the International Space Station

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import time

isslocations = []
interval = 10
url = "http://api.open-notify.org/iss-now.json"

for i in range (100):
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        isslocations.append((float(data["iss_position"]["latitude"]), float(data["iss_position"]["longitude"]), data["timestamp"]))
        time.sleep(interval)

# %%
import matplotlib.pyplot as plt

lats = [location[0] for location in isslocations]
longs = [location[1] for location in isslocations]

plt.plot(longs, lats)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Path of the ISS")

plt.show()
